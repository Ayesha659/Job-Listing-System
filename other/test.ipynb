# %%
import pandas as pd

# %%
data = pd.read_csv("pk.csv")
data.head()
# Out:
#                                                 href label  \
# 0  https://pk.indeed.com/company/PAKISTAN-TELECOM...   new
# 1  https://pk.indeed.com/company/Estate-Adz/jobs/...   NaN
# 2  https://pk.indeed.com/rc/clk?jk=573751543fce52...   NaN
# 3  https://pk.indeed.com/company/Estate-Adz/jobs/...   NaN
# 4  https://pk.indeed.com/company/STAR-Marketing/j...   NaN
#
#                                             jobTitle  \
# 0     PTCL Official Helpline 1236/1218 - Male/Female
# 1  Fresh Students Required / online / office / pa...
# 2                             Data Entry Work Online
# 3                                  Office Supervisor
# 4                              Need Matric Candidate
#
#                                   companyName companyLocation  \
# 0  PAKISTAN TELECOMMUNICATION COMPANY LIMITED          Lahore
# 1                                  Estate Adz      Rawalpindi
# 2                                  Click Jobs          Lahore
# ...

# %%
data.isnull().sum()
# Out:
# href                 0
# label              345
# jobTitle             0
# companyName        105
# companyLocation      0
# salary-snippet     147
# ialbl               98
# job-snippet          0
# date                 0
# shelfItem          318
# job-snippet 2      194
# job-snippet 3      413
# dtype: int64

# %%
data.shape
# Out:
# (523, 12)

# %%
data.ialbl.unique()
# Out:
# array(['Easily apply', nan, 'Easily apply to this job without a resume'],
#       dtype=object)

# %%
data[data.columns[0]].nunique()
# Out:
# 494

# %%
data.columns
# Out:
# Index(['href', 'label', 'jobTitle', 'companyName', 'companyLocation',
#        'salary-snippet', 'ialbl', 'job-snippet', 'date', 'shelfItem',
#        'job-snippet 2', 'job-snippet 3'],
#       dtype='object')

# %%
data
# Out:
#                                                   href label  \
# 0    https://pk.indeed.com/company/PAKISTAN-TELECOM...   new
# 1    https://pk.indeed.com/company/Estate-Adz/jobs/...   NaN
# 2    https://pk.indeed.com/rc/clk?jk=573751543fce52...   NaN
# 3    https://pk.indeed.com/company/Estate-Adz/jobs/...   NaN
# 4    https://pk.indeed.com/company/STAR-Marketing/j...   NaN
# ..                                                 ...   ...
# 518  https://pk.indeed.com/rc/clk?jk=6f3870d15b6397...   NaN
# 519  https://pk.indeed.com/company/Usama-Call-Cente...   NaN
# 520  https://pk.indeed.com/rc/clk?jk=28bfc3bd44a37e...   NaN
# 521  https://pk.indeed.com/rc/clk?jk=b4c9303cb442c8...   NaN
# 522  https://pk.indeed.com/rc/clk?jk=b5eab6c4ca9624...   NaN
#
#                                               jobTitle  \
# 0       PTCL Official Helpline 1236/1218 - Male/Female
# 1    Fresh Students Required / online / office / pa...
# 2                               Data Entry Work Online
# ...
